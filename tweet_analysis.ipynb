# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

import tensorflow
from tensorflow import keras
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout,LSTM

from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
data= pd.read_csv ("/content/drive/MyDrive/Datasets/data_tweet_analysis.csv")

# %%
data.head(3)
# Out:
#    UserName  ...           Sentiment
# 0         1  ...  Extremely Negative
# 1         2  ...            Positive
# 2         3  ...  Extremely Positive
#
# [3 rows x 6 columns]

# %%
data.OriginalTweet[0]
# Out:
# 'TRENDING: New Yorkers encounter empty supermarket shelves (pictured, Wegmans in Brooklyn), sold-out online grocers (FoodKick, MaxDelivery) as #coronavirus-fearing shoppers stock up https://t.co/Gr76pcrLWh https://t.co/ivMKMsqdT1'

# %%
data.Sentiment.value_counts()
# Out:
# Negative              1041
# Positive               947
# Neutral                619
# Extremely Positive     599
# Extremely Negative     592
# Name: Sentiment, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       3798 non-null   int64
#  1   ScreenName     3798 non-null   int64
#  2   Location       2964 non-null   object
#  3   TweetAt        3798 non-null   object
#  4   OriginalTweet  3798 non-null   object
#  5   Sentiment      3798 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 178.2+ KB

# %%
data.Location.value_counts()
# Out:
# United States               75
# London, England             48
# Washington, DC              38
# New York, NY                34
# Los Angeles, CA             33
#                             ..
# Distrito Federal, México     1
# Plymouth UK                  1
# Wakefield, UK                1
# Corpus Christi, TX           1
# SF Native/Peninsula          1
# Name: Location, Length: 1717, dtype: int64

# %%
data.Location.describe()
# Out:
# count              2964
# unique             1717
# top       United States
# freq                 75
# Name: Location, dtype: object

# %%
# filling in missing values by the most frequent
data = data.fillna (data.Location.describe()[2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       3798 non-null   int64
#  1   ScreenName     3798 non-null   int64
#  2   Location       3798 non-null   object
#  3   TweetAt        3798 non-null   object
#  4   OriginalTweet  3798 non-null   object
#  5   Sentiment      3798 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 178.2+ KB

# %%
data.Location.value_counts()
# Out:
# United States               909
# London, England              48
# Washington, DC               38
# New York, NY                 34
# Los Angeles, CA              33
#                            ...
# Distrito Federal, México      1
# Plymouth UK                   1
# Wakefield, UK                 1
# Corpus Christi, TX            1
# SF Native/Peninsula           1
# Name: Location, Length: 1717, dtype: int64

# %%
# label encoding the target
data['Sentiment'].replace('Extremely Negative',0,inplace=True)
data['Sentiment'].replace('Negative',1,inplace=True)
data['Sentiment'].replace('Neutral',2,inplace=True)
data['Sentiment'].replace('Positive',3,inplace=True)
data['Sentiment'].replace('Extremely Positive',4,inplace=True)

print (data.Sentiment.value_counts())
# Out:
# 1    1041
# 3     947
# 2     619
# 4     599
# 0     592
# Name: Sentiment, dtype: int64

# %%
x=data.drop('Sentiment',axis=1)
y=data['Sentiment'].values
print(y)
y=y.reshape(-1,1)
print(y)
# Out:
# [0 3 4 ... 2 0 4]
# [[0]
#  [3]
#  [4]
#  ...
#  [2]
#  [0]
#  [4]]

# %%
# Text Preprocessing
nltk.download('stopwords')
message=x.copy()
message.reset_index(inplace=True)

ps=PorterStemmer()
corpus=[]
for i in range(len(x)):
  review=re.sub('[^a-zA-Z]',' ',message['OriginalTweet'][i])
  review=review.lower()
  review=review.split()
  review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
  review=' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(corpus)
# Out:
# ['trend new yorker encount empti supermarket shelv pictur wegman brooklyn sold onlin grocer foodkick maxdeliveri coronaviru fear shopper stock http co gr pcrlwh http co ivmkmsqdt', 'find hand sanit fred meyer turn amazon pack purel check coronaviru concern drive price http co ygbipbflmi', 'find protect love one coronaviru', 'panic buy hit newyork citi anxiou shopper stock food amp medic suppli healthcar worker becom bigappl st confirm coronaviru patient bloomberg stage event http co iasiregpc qanon qanon qanon elect cdc http co iszoewxu', 'toiletpap dunnypap coronaviru coronavirusaustralia coronavirusupd covid news corvid newsmelb dunnypaperg costco one week everyon buy babi milk powder next everyon buy toilet paper http co sczryvvsih', 'rememb last time paid gallon regular ga lo angel price pump go look coronaviru impact price pm abc http co pyzq ymuv', 'vote age coronaviru hand sanit supertuesday http co z bel dk', 'drtedro stop covid without protect healthwork price surgic mask increas six fold n respir trebl amp gown cost twice much drtedro coronaviru', 'hi twitter pharmacist sell hand sanit live exist like mask sold fuck everywher worri use soap visit twenti pharmaci look last bottl pharmaci full sick peopl', 'anyon supermarket last day went normal shop last night amp sight greet barmi btw special tin tomato covid dublin http co rgsm xuxr', 'best qualiti couch unbeliev low price avail order boksburg gp info whatsapp supertuesdsi powertalk covid sayentrepreneur djsbu http co hhdjhyq dc', 'bewar counterfeit tri sell fake mask cheap price let defeat coronaviru threat covid collect besaf beacascad coronavirusreachesdelhi coronavirusindia http co ikkmimj f http co rb rtt nkc', 'panic food buy germani due coronaviru begun organ left behind hamsterkauf panic buy call hamster purchas hamsterk ufe german taken way hamster stuff cheek food http co ayqtllgw', 'covid went groceri store turn clean suppli bought fear coronaviru daughter substitut teacher show class make hand sanit need buy alcohol wish luck store', 'busi watch elect return brace covid outbreak trump nomin chemic industri lobbyist head consum product safeti commiss http co shhi tn', 'airsewa flyspicejet provid webchecin custom free seat passeng forc choos paid seat free seat made avail airport counter stop discriminatori travel right hardeepspuri moca goi', 'precautionari measur taken respect restaur hotel comment covid coronaviru covid hotel chain enforc precautionari measur issu safeti hygien advisori http co zo vqspzi', 'stockpil food amp suppli buy extra local food bank mani famili luxuri spend beyond weekli budget dailybreadto coronaviru', 'week bit optimist probabl take anoth month suppli chain may recov demand chain non exist us europ next month two spx qqq es nq http co yxcofl bni', 'studi show coronaviru like covid live nine day hard surfac like
 41261, 35413, 20533, 15637, 26379, 14117, 9943, 20827, 16178, 15857, 42262, 20827, 16178, 36700, 36679, 8817], [24600, 40663, 25222, 14620, 48737, 49371, 26802, 9374, 3505, 33456, 48158, 24600, 25222, 23534, 34664, 38192, 30856, 38160, 9892, 49790, 4562, 34664, 7545, 18420, 40663, 20827, 16178, 22665], [35413, 26474, 36950, 48092, 40137, 34538, 5194, 45413, 28760, 49371, 45972, 30973, 35702, 45553, 40047, 48736, 287, 33225, 31159, 25222, 47499, 9382, 11125, 48092], [7672, 28771, 3346, 27285, 39034, 35413, 19805, 43100, 39094, 42876, 16949, 34416, 20220, 17045, 34784, 40849, 2067, 20827, 16178, 39335, 39679], [42113, 27293, 27294, 20599, 47556, 26464, 34475, 24044, 21350, 29971, 1620, 34475, 26464, 34475, 15281, 36892, 16536, 27155, 35641, 9874, 16321, 45979, 37901, 31873, 46459], [31596, 28221, 49790, 13613, 46624, 15685, 21885, 35413, 49371, 35413, 15685, 29705, 12167, 31596, 28221, 17576, 40849, 21575, 38219, 20827, 16178, 18619, 28346], [24252, 40663, 28451, 5194, 25222, 3716, 42413, 40663, 46313, 38606, 29554, 38485, 22060, 35109, 1522, 47918, 5429, 49371], [31038, 47122, 33410, 39287, 8548, 38394, 336, 5194, 29705, 19977, 19776, 29910, 29705, 912, 48421, 9254, 36056, 27702, 336, 26980, 39732, 13311, 15524, 28390, 20827, 16178, 15128, 40501], [24092, 45553, 49371, 12421, 35413, 21908, 31507, 624, 14056, 19530, 12421, 12534, 42612, 31419, 21840, 5636, 17045, 12885, 7181, 49469, 14026, 45553, 24349, 34538, 44119, 45673, 28771, 20031, 20827, 16178, 9214, 45067], [49371, 35413, 9276, 45724, 11310, 12442, 42828, 38606, 10892, 20911, 40137, 42228, 42729, 48655, 33714, 28451, 47055, 23225, 48655, 48655, 47636, 40277, 32538, 2676, 20827, 16178, 45067, 27415], [3248, 28640, 25087, 42729, 23528, 18344, 23450, 49371, 24349, 21883, 35561, 6690, 38606, 9276, 36950, 48092, 44119, 6092, 1907, 31301, 11466, 624, 20827, 16178, 21412, 43060, 5351], [49827, 17998, 47773, 5301, 47773, 18344, 33215, 40563, 11388, 30402, 25339, 3853, 6335, 49371, 44894, 8019, 39615, 6174, 22155, 8019, 37163, 10054, 34566, 38606, 20827, 16178, 16604, 6629, 9902], [22397, 12987, 24600, 27067, 33714, 33225, 16554, 33498, 40277, 41291, 9490, 33225, 33714, 5806, 27074, 49371, 43112, 28771, 6041, 20827, 16178, 44586, 22356], [31250, 7995, 39034, 8416, 26133, 32283, 40277, 19084, 7843, 30263, 1013, 28544, 39297, 11390, ...

# %%
sent_length=30
input=pad_sequences(one_hot_r,padding='pre',maxlen=sent_length)

final_x=np.array(input)
final_y=np.array(y)

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(final_x,final_y, test_size=0.33, random_state=42)
print(x_train.shape)
print(y_train.shape)
# Out:
# (2544, 30)
# (2544, 1)

# %% [markdown]
# ## MODEL BUILDING: MODEL #1

# %%
dim=40
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(80))
model.add(Dropout(0.3))
model.add(Dense(1,activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 30, 40)            2000000
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 40)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 80)                38720
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 81
# =================================================================
# Total params: 2,038,801
# Trainable params: 2,038,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size=50,epochs=10,validation_data=(x_test,y_test), verbose = 2)
# Out:
# Epoch 1/120
# 51/51 - 6s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 2/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 3/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 4/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 5/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 6/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 7/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 8/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 9/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 10/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 11/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 12/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 13/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 14/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 15/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 16/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 17/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 18/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 19/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 20/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 21/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 22/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 23/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 24/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 25/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 26/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 27/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 28/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 29/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 30/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 31/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 32/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 33/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 34/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 35/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 36/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 37/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 38/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 39/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 40/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 41/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 42/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 43/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 44/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 45/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 46/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 47/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 48/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 49/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 50/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 51/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 52/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 53/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 54/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 55/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 56/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 57/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 58/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 59/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 60/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 61/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 62/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 63/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 64/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 65/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 66/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 67/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 68/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 69/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 70/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 71/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 72/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 73/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 74/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 75/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 76/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 77/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 78/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 79/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 80/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 81/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 82/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 83/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 84/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 85/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 86/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 87/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 88/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 89/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 90/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 91/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 92/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 93/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 94/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 95/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 96/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 97/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 98/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 99/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 100/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 101/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 102/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 103/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 104/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 105/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 106/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 107/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 108/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 109/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 110/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 111/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 112/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 113/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 114/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 115/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 116/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 117/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 118/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 119/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 120/120
# 51/51 - 3s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624

# %%
y_pred=model.predict(x_test)

val=metrics.accuracy_score(y_test,y_pred)
print("accuracy is =",str(val*100)+" %")
# Out:
# accuracy is = 26.236044657097292 %

# %% [markdown]
# ## MODEL #2

# %%
from keras.layers import Bidirectional
dim=120
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Bidirectional(LSTM(32)))
model.add(Dense(1,activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 30, 120)           6000000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 30, 128)           94720
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 6,136,001
# Trainable params: 6,136,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size=50,epochs=10,validation_data=(x_test,y_test), verbose = 2)
# Out:
# Epoch 1/10
# 51/51 - 17s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 2/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 3/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 4/10
# 51/51 - 9s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 5/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 6/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 7/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 8/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 9/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624
# Epoch 10/10
# 51/51 - 8s - loss: 0.0000e+00 - accuracy: 0.2799 - val_loss: 0.0000e+00 - val_accuracy: 0.2624

# %%
y_pred1=model.predict(x_test)

val=metrics.accuracy_score(y_test,y_pred1)
print("accuracy is =",str(val*100)+" %")
# Out:
# accuracy is = 26.236044657097292 %
